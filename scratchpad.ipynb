# %% [markdown]
# <a href="https://colab.research.google.com/github/moongoldpk/Adidas-US-Sales-Dataset-Analysis/blob/main/scratchpad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create requirements.txt using echo
# !echo "pandas" > requirements.txt
# !echo "numpy" >> requirements.txt
# !echo "matplotlib" >> requirements.txt
# !echo "seaborn" >> requirements.txt
# !echo "scikit-learn" >> requirements.txt
# !echo "kagglehub" >> requirements.txt

# Install
# !pip install -r requirements.txt
# !pip install -r requirements.txt

# %%
# ============================================
# COLAB + GITHUB STARTER TEMPLATE (FIXED)
# ============================================

# 1. Clone your repository
# !git clone https://github.com/moongoldpk/Adidas-US-Sales-Dataset-Analysis.git

# 2. Navigate into the repo folder
# %cd Adidas-US-Sales-Dataset-Analysis

# 3. Pull latest changes
# !git pull origin main

# 4. Install required packages directly (no requirements.txt needed)
# !pip install pandas numpy matplotlib seaborn scikit-learn kagglehub

# 5. Check status
# !git status

print("✅ All setup complete! You're ready to work.")
# Out:
# Cloning into 'Adidas-US-Sales-Dataset-Analysis'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 58 (delta 11), reused 49 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 9.57 MiB | 15.68 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
# /content/Adidas-US-Sales-Dataset-Analysis/Adidas-US-Sales-Dataset-Analysis/Adidas-US-Sales-Dataset-Analysis
# From https://github.com/moongoldpk/Adidas-US-Sales-Dataset-Analysis
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# ...
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# ✅ All setup complete! You're ready to work.

# %%
# %cd /content/Adidas-US-Sales-Dataset-Analysis
# !pip install pandas numpy matplotlib seaborn scikit-learn kagglehub
# !git pull origin main
# Out:
# /content/Adidas-US-Sales-Dataset-Analysis
# ...
# From https://github.com/moongoldpk/Adidas-US-Sales-Dataset-Analysis
#  * branch            main       -> FETCH_HEAD
# Already up to date.
